# %%
! nvidia-smi
# Out:
# Mon Mar 24 13:58:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
! pip install IPython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.6 MB/s eta 0:00:00
# ...

# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import IPython
import ultralytics
from IPython import display
from IPython.display import Image

from ultralytics import YOLO


display.clear_output()

ultralytics.checks()
# Out:
# Ultralytics 8.3.95 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.1/112.6 GB disk)

# %%
import os
HOME = os.getcwd()

print(HOME)
# Out:
# /content

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 140MB/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="b2KtWuEPlX7paujV1Yuw")
project = rf.workspace("computervisionproblem").project("breast_cancer_capstone1-rfekc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 106.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to breast_cancer_capstone1-1 in yolov11:: 100%|██████████| 5276/5276 [00:00<00:00, 6396.36it/s]

# %%
# %cd {HOME}

! yolo task = detect mode=train model = yolo11n.pt data={dataset.location}/data.yaml epochs=30 imgsz=700 plots=True
# Out:
# /content
# Ultralytics 8.3.95 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
! ls /content/runs/detect/train3
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1742825596.0962b0f9bc2e.4397.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1780.jpg  val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch1781.jpg  val_batch2_pred.jpg
# labels.jpg					    train_batch1782.jpg  weights
# P_curve.png					    train_batch1.jpg
# PR_curve.png					    train_batch2.jpg

# %%
# %cd {HOME}
from PIL import Image
from IPython.display import display
image = Image.open(f'/content/runs/detect/train3/P_curve.png')
image.resize((600,600))
display(image)
# Out:
# /content
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
# %cd {HOME}
from PIL import Image
from IPython.display import display
image = Image.open(f'/content/runs/detect/train3/results.png')
image.resize((600,600))
display(image)
# Out:
# /content
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
# %cd {HOME}
from PIL import Image
from IPython.display import display
image = Image.open(f'/content/runs/detect/train3/F1_curve.png')
image.resize((600,600))
display(image)
# Out:
# /content
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
# %cd {HOME}
from PIL import Image
from IPython.display import display
image = Image.open(f'/content/runs/detect/train3/R_curve.png')
image.resize((600,600))
display(image)
# Out:
# /content
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
from IPython.display import Image
# %cd {HOME}

Image(filename=f'{HOME}/runs/detect/train3/PR_curve.png',width=600)
# Out:
# /content

# %%
from IPython.display import Image
# %cd {HOME}

Image(filename=f'{HOME}/runs/detect/train3/confusion_matrix.png',width=600)
# Out:
# /content

# %%
# %cd {HOME}

Image(filename=f'{HOME}/runs/detect/train3/R_curve.png',width=600)
# Out:
# /content

# %%
# %cd {HOME}
from IPython.display import Image

Image(filename=f'/content/runs/detect/train3/train_batch0.jpg',width=800)
# Out:
# /content

# %%
# %cd {HOME}

Image(filename=f'{HOME}/runs/detect/train3/train_batch1.jpg',width=800)
# Out:
# /content
